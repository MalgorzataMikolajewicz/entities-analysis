# %%
from google.cloud import language_v1
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="fluent-oarlock-xxxxxx-xxxxxxxxxxxx.json"

import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen

htmls = input('Enter the web address to get the entities'),

def parse(url):        
    x = urlopen(url).read()
    x = BeautifulSoup(x, "lxml").find_all("p")
    return(x)

articles = [parse(url) for url in htmls]

articles = [" ".join([str(paragraph) for paragraph in article]) for article in articles]

def sample_analyze_entities(text_content):
    """
    Analyzing Entities in a String

    Args:
      text_content The text content to analyze
    """

    client = language_v1.LanguageServiceClient()

    text_content = text_content

    # Available types: PLAIN_TEXT, HTML
    type_ = language_v1.Document.Type.HTML

    # Optional. If not specified, the language is automatically detected.
    # For list of supported languages:
    # https://cloud.google.com/natural-language/docs/languages
    language = "en"
    document = {"content": text_content, "type_": type_, "language": language}

    # Available values: NONE, UTF8, UTF16, UTF32
    encoding_type = language_v1.EncodingType.UTF8

    response = client.analyze_entities(request = {'document': document, 'encoding_type': encoding_type})

    # Loop through entitites returned from the API
    for entity in response.entities:
        print(u"Representative name for the entity: {}".format(entity.name))

        # Get entity type, e.g. PERSON, LOCATION, ADDRESS, NUMBER, et al
        print(u"Entity type: {}".format(language_v1.Entity.Type(entity.type_).name))

        # Get the salience score associated with the entity in the [0, 1.0] range
        print(u"Salience score: {}".format(entity.salience))

        # Loop over the metadata associated with entity. For many known entities,
        # the metadata is a Wikipedia URL (wikipedia_url) and Knowledge Graph MID (mid).
        # Some entity types may have additional metadata, e.g. ADDRESS entities
        # may have metadata for the address street_name, postal_code, et al.
        for metadata_name, metadata_value in entity.metadata.items():
            print(u"{}: {}".format(metadata_name, metadata_value))

        # Loop over the mentions of this entity in the input document.
        # The API currently supports proper noun mentions.
        for mention in entity.mentions:
            print(u"Mention text: {}".format(mention.text.content))

            # Get the mention type, e.g. PROPER for proper noun
            print(
                u"Mention type: {}".format(language_v1.EntityMention.Type(mention.type_).name)
            )
        print('\n')

    # Get the language of the text, which will be the same as
    # the language specified in the request or, if not specified,
    # the automatically-detected language.
    print(u"Language of the text: {}".format(response.language))
sample_analyze_entities(articles[0])
# Out:
# Enter the web address to get the entities https://www.degruyter.com/document/doi/10.1515/cclm-2017-0287/html
# Representative name for the entity: ML
# Entity type: LOCATION
# Salience score: 0.15431566536426544
# mid: /m/01hyh_
# wikipedia_url: https://en.wikipedia.org/wiki/Machine_learning
# Mention text: ML
# Mention type: COMMON
# Mention text: ML
# Mention type: COMMON
# Mention text: ML
# Mention type: COMMON
# Mention text: ML
# Mention type: COMMON
# Mention text: ML
# Mention type: COMMON
# Mention text: ML
# Mention type: COMMON
# Mention text: ML
# Mention type: COMMON
# Mention text: ML
# Mention type: COMMON
# Mention text: ML
# Mention type: COMMON
# Mention text: ML
# Mention type: COMMON
# Mention text: ML
# Mention type: COMMON
# Mention text: ML
# Mention type: PROPER
# Mention text: ML
# Mention type: COMMON
# Mention text: ML
# Mention type: COMMON
# Mention text: ML
# Mention type: PROPER
# Mention text: ML
# Mention type: PROPER
# Mention text: ML
# Mention type: PROPER
# Mention text: ML
# Mention type: PROPER
# Mention text: ML
# Mention type: PROPER
# Mention text: ML
# Mention type: PROPER
# Mention text: ML
# Mention type: PROPER
# Mention text: ML
# Mention type: PROPER
# Mention text: ML
# Mention type: PROPER
# Mention text: ML
# Mention type: PROPER
# Mention text: ML
# Mention type: PROPER
#
#
# Representative name for the entity: data sets
# Entity type: OTHER
# Salience score: 0.027043789625167847
# Mention text: data
# Mention type: COMMON
# Mention text: data sets
# Mention type: COMMON
#
#
# Representative name for the entity: Search
# Entity type: OTHER
# Salience score: 0.00937498826533556
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
# Mention text: Search
# Mention type: COMMON
#
#
# Representative name for the entity: training data
# Entity type: OTHER
# Salience score: 0.009275801479816437
# Mention text: training data
# Mention type: COMMON
# Mention text: training data
# Mention type: COMMON
#
#
# Representative name for the entity: cross-validation
# Entity type: OTHER
# Salience score: 0.008910170756280422
# Mention text: technique
# Mention type: COMMON
# Mention text: cross-validation
# Mention type: COMMON
#
#
# Representative name for the entity: number
# Entity type: OTHER
# Salience score: 0.008779061026871204
# Mention text: value
# Mention type: COMMON
# Mention text: number
# Mention type: COMMON
#
#
# Representative name for the entity: y
# Entity type: OTHER
# Salience score: 0.008450600318610668
# Mention text: y
# Mention type: COMMON
# Mention text: y
# Mention type: COMMON
#
#
# Representative name for the entity: value
# Entity type: OTHER
# Salience score: 0.006422708742320538
# Mention text: value
# Mention type: COMMON
#
#
# Representative name for the entity: machine learning
# Entity type: OTHER
# Salience score: 0.00609589321538806
# Mention text: machine learning
# Mention type: COMMON
# Mention text: Machine learning
# Mention type: COMMON
#
#
# Representative name for the entity: Kume T
# Entity type: OTHER
# Salience score: 0.005804150830954313
# Mention text: T
# Mention type: COMMON
# Mention text: T
# Mention type: PROPER
# Mention text: T
# Mention type: PROPER
# Mention text: task
# Mention type: COMMON
# Mention text: Kume T
# Mention type: PROPER
#
#
# Representative name for the entity: parameters
# Entity type: OTHER
# Salience score: 0.005646043922752142
# Mention text: parameters
# Mention type: COMMON
# Mention text: parameters
# Mention type: COMMON
#
#
# Representative name for the entity: Overfitting
# Entity type: OTHER
# Salience score: 0.004945341031998396
# wikipedia_url: https://en.wikipedia.org/wiki/Overfitting
# mid: /m/017chx
# Mention text: Overfitting
# Mention type: PROPER
# Mention text: Overfitting
# Mention type: PROPER
#
#
# Representative name for the entity: interval
# Entity type: OTHER
# Salience score: 0.004827583208680153
# Mention text: scale
# Mention type: COMMON
# Mention text: interval
# Mention type: COMMON
#
#
# Representative name for the entity: values
# Entity type: OTHER
# Salience score: 0.0042837830260396
# Mention text: values
# Mention type: COMMON
#
#
# Representative name for the entity: methods
# Entity type: OTHER
# Salience score: 0.004146057181060314
# Mention text: methods
# Mention type: COMMON
#
#
# Representative name for the entity: data model
# Entity type: OTHER
# Salience score: 0.0040561845526099205
# Mention text: data model
# Mention type: COMMON
#
#
# Representative name for the entity: task
# Entity type: OTHER
# Salience score: 0.004049530252814293
# Mention text: task
# Mention type: COMMON
#
#
# Representative name for the entity: patient
# Entity type: PERSON
# Salience score: 0.0038778381422162056
# Mention text: patient
# Mention type: COMMON
#
#
# Representative name for the entity: terms
# Entity type: OTHER
# Salience score: 0.003464018926024437
# Mention text: terms
# Mention type: COMMON
#
#
# Representative name for the entity: classification model
# Entity type: OTHER
# Salience score: 0.003451611613854766
# Mention text: classification model
# Mention type: COMMON
#
#
# Representative name for the entity: support vector machines
# Entity type: CONSUMER_GOOD
# Salience score: 0.003074157051742077
# Mention text: support vector machines
# Mention type: COMMON
# Mention text: performing models
# Mention type: COMMON
#
#
# Representative name for the entity: x
# Entity type: OTHER
# Salience score: 0.0029362733475863934
# Mention text: x
# Mention type: COMMON
#
#
# Representative name for the entity: model
# Entity type: OTHER
# Salience score: 0.0028741939458996058
# Mention text: model
# Mention type: COMMON
#
#
# Representative name for the entity: physician-scientists
# Entity type: PERSON
# Salience score: 0.002858172869309783
# Mention text: physician-scientists
# Mention type: COMMON
#
#
# Representative name for the entity: models
# Entity type: CONSUMER_GOOD
# Salience score: 0.0026564213912934065
# Mention text: models
# Mention type: COMMON
#
#
# Representative name for the entity: black box
# Entity type: OTHER
# Salience score: 0.002622014144435525
# Mention text: black box
# Mention type: COMMON
#
#
# Representative name for the entity: process
# Entity type: OTHER
# Salience score: 0.0025716745294630527
# Mention text: process
# Mention type: COMMON
#
#
# Representative name for the entity: models
# Entity type: CONSUMER_GOOD
# Salience score: 0.0024467571638524532
# Mention text: models
# Mention type: COMMON
#
#
# Representative name for the entity: model
# Entity type: OTHER
# Salience score: 0.0024164842907339334
# Mention text: model
# Mention type: COMMON
#
#
# Representative name for the entity: model
# Entity type: OTHER
# Salience score: 0.0024138980079442263
# Mention text: model
# Mention type: COMMON
#
#
# Representative name for the entity: ML models
# Entity type: CONSUMER_GOOD
# Salience score: 0.002407277934253216
# Mention text: ML models
# Mention type: COMMON
#
#
# Representative name for the entity: machine
# Entity type: CONSUMER_GOOD
# Salience score: 0.0024060646537691355
# Mention text: machine
# Mention type: COMMON
#
#
# Representative name for the entity: model
# Entity type: CONSUMER_GOOD
# Salience score: 0.002405366627499461
# Mention text: model
# Mention type: COMMON
#
#
# Representative name for the entity: ML models
# Entity type: CONSUMER_GOOD
# Salience score: 0.002401882316917181
# Mention text: ML models
# Mention type: COMMON
#
#
# Representative name for the entity: laboratory data
# Entity type: OTHER
# Salience score: 0.002400325145572424
# Mention text: laboratory data
# Mention type: COMMON
#
#
# Representative name for the entity: model
# Entity type: OTHER
# Salience score: 0.002400284633040428
# Mention text: model
# Mention type: COMMON
#
#
# Representative name for the entity: model
# Entity type: OTHER
# Salience score: 0.002397329779341817
# Mention text: model
# Mention type: COMMON
#
#
# Representative name for the entity: testing data
# Entity type: OTHER
# Salience score: 0.0023875064216554165
# Mention text: testing data
# Mention type: COMMON
#
#
# Representative name for the entity: data
# Entity type: OTHER
# Salience score: 0.0023746013175696135
# Mention text: data
# Mention type: COMMON
#
#
# Representative name for the entity: data
# Entity type: OTHER
# Salience score: 0.00236120936460793
# Mention text: data
# Mention type: COMMON
#
#
# Representative name for the entity: training data
# Entity type: OTHER
# Salience score: 0.00236120936460793
# Mention text: training data
# Mention type: COMMON
#
#
# Representative name for the entity: models
# Entity type: OTHER
# Salience score: 0.002324555302038789
# Mention text: models
# Mention type: COMMON
# Mention text: models
# Mention type: COMMON
#
#
# Representative name for the entity: medicine
# Entity type: OTHER
# Salience score: 0.002302012173458934
# Mention text: medicine
# Mention type: COMMON
# Mention text: medicine
# Mention type: COMMON
#
#
# Representative name for the entity: process
# Entity type: OTHER
# Salience score: 0.002283999929204583
# Mention text: process
# Mention type: COMMON
#
#
# Representative name for the entity: Bias
# Entity type: OTHER
# Salience score: 0.0021990002132952213
# mid: /m/0b56z
# wikipedia_url: https://en.wikipedia.org/wiki/Bias
# Mention text: Bias
# Mention type: PROPER
# Mention text: error
# Mention type: COMMON
#
#
# Representative name for the entity: learning
# Entity type: OTHER
# Salience score: 0.0021816135849803686
# Mention text: learning
# Mention type: COMMON
#
#
# Representative name for the entity: learners
# Entity type: PERSON
# Salience score: 0.0021816135849803686
# Mention text: learners
# Mention type: COMMON
#
#
# Representative name for the entity: potential
# Entity type: OTHER
# Salience score: 0.0021794410422444344
# Mention text: potential
# Mention type: COMMON
#
#
# Representative name for the entity: mapping
# Entity type: OTHER
# Salience score: 0.0021560825407505035
# Mention text: mapping
# Mention type: COMMON
#
#
# Representative name for the entity: Lin et al.
# Entity type: PERSON
# Salience score: 0.0020553297363221645
# Mention text: Lin et al.
# Mention type: PROPER
#
#
# Representative name for the entity: risk
# Entity type: OTHER
# Salience score: 0.0020273602567613125
# Mention text: risk
# Mention type: COMMON
#
#
# Representative name for the entity: value
# Entity type: OTHER
# Salience score: 0.002024272456765175
# Mention text: value
# Mention type: COMMON
#
#
# Representative name for the entity: model
# Entity type: OTHER
# Salience score: 0.002008326817303896
# Mention text: model
# Mention type: COMMON
# Mention text: model
# Mention type: COMMON
#
#
# Representative name for the entity: records
# Entity type: OTHER
# Salience score: 0.0020051186438649893
# Mention text: records
# Mention type: COMMON
# Mention text: records
# Mention type: COMMON
#
#
# Representative name for the entity: learners
# Entity type: PERSON
# Salience score: 0.001977029489353299
# Mention text: learners
# Mention type: COMMON
#
#
# Representative name for the entity: laboratory medicine
# Entity type: OTHER
# Salience score: 0.0019755582325160503
# Mention text: laboratory medicine
# Mention type: COMMON
#
#
# Representative name for the entity: machines
# Entity type: OTHER
# Salience score: 0.0019710795022547245
# Mention text: machines
# Mention type: COMMON
#
#
# Representative name for the entity: laboratory medicine
# Entity type: OTHER
# Salience score: 0.001970139564946294
# Mention text: laboratory medicine
# Mention type: COMMON
#
#
# Representative name for the entity: medicine
# Entity type: OTHER
# Salience score: 0.0019657230004668236
# Mention text: medicine
# Mention type: COMMON
#
#
# Representative name for the entity: laboratory medicine
# Entity type: OTHER
# Salience score: 0.0019587744027376175
# Mention text: laboratory medicine
# Mention type: COMMON
#
#
# Representative name for the entity: medicine
# Entity type: OTHER
# Salience score: 0.001953401602804661
# Mention text: medicine
# Mention type: COMMON
#
#
# Representative name for the entity: Data scientists program machines
# Entity type: OTHER
# Salience score: 0.0019530333811417222
# Mention text: Data scientists program machines
# Mention type: COMMON
#
#
# Representative name for the entity: value
# Entity type: OTHER
# Salience score: 0.0019050298724323511
# Mention text: value
# Mention type: COMMON
#
#
# Representative name for the entity: machine learning
# Entity type: OTHER
# Salience score: 0.0018950185040012002
# Mention text: machine learning
# Mention type: COMMON
#
#
# Representative name for the entity: machine learning
# Entity type: OTHER
# Salience score: 0.0018898204434663057
# Mention text: machine learning
# Mention type: COMMON
#
#
# Representative name for the entity: machine learning
# Entity type: OTHER
# Salience score: 0.0018590182298794389
# Mention text: machine learning
# Mention type: COMMON
#
#
# Representative name for the entity: healthcare professionals
# Entity type: PERSON
# Salience score: 0.0018270297441631556
# Mention text: healthcare professionals
# Mention type: COMMON
#
#
# Representative name for the entity: feedback loop
# Entity type: OTHER
# Salience score: 0.0018133687553927302
# Mention text: feedback loop
# Mention type: COMMON
# Mention text: learning
# Mention type: COMMON
#
#
# Representative name for the entity: classification
# Entity type: OTHER
# Salience score: 0.0017675536219030619
# Mention text: classification
# Mention type: COMMON
#
#
# Representative name for the entity: class
# Entity type: OTHER
# Salience score: 0.0017587532056495547
# Mention text: class
# Mention type: COMMON
#
#
# Representative name for the entity: number
# Entity type: OTHER
# Salience score: 0.001756517682224512
# Mention text: number
# Mention type: COMMON
#
#
# Representative name for the entity: methods
# Entity type: OTHER
# Salience score: 0.0017461003735661507
# Mention text: methods
# Mention type: COMMON
#
#
# Representative name for the entity: model
# Entity type: OTHER
# Salience score: 0.0017454017652198672
# Mention text: model
# Mention type: COMMON
#
#
# Representative name for the entity: hyperparathyroidism
# Entity type: OTHER
# Salience score: 0.001738094724714756
# Mention text: hyperparathyroidism
# Mention type: COMMON
# Mention text: hyperparathyroidism
# Mention type: COMMON
# Mention text: hyperparathyroidism
# Mention type: COMMON
# Mention text: hyperparathyroidism
# Mention type: COMMON
#
#
# Representative name for the entity: umbrella term
# Entity type: OTHER
# Salience score: 0.001730043557472527
# Mention text: umbrella term
# Mention type: COMMON
#
#
# Representative name for the entity: Putin et al.
# Entity type: PERSON
# Salience score: 0.0017281160689890385
# Mention text: Putin et al.
# Mention type: PROPER
#
#
# Representative name for the entity: data scientists
# Entity type: PERSON
# Salience score: 0.0017155626555904746
# Mention text: data scientists
# Mention type: COMMON
#
#
# Representative name for the entity: value
# Entity type: OTHER
# Salience score: 0.001684637158177793
# Mention text: value
# Mention type: COMMON
#
#
# Representative name for the entity: values
# Entity type: OTHER
# Salience score: 0.0016800157027319074
# Mention text: values
# Mention type: COMMON
#
#
# Representative name for the entity: values
# Entity type: OTHER
# Salience score: 0.0016786814667284489
# Mention text: values
# Mention type: COMMON
#
#
# Representative name for the entity: variance
# Entity type: OTHER
# Salience score: 0.0016660952242091298
# Mention text: variance
# Mention type: COMMON
# Mention text: variance
# Mention type: COMMON
#
#
# Representative name for the entity: artificial intelligence
# Entity type: OTHER
# Salience score: 0.0016643841518089175
# Mention text: artificial intelligence
# Mention type: COMMON
#
#
# Representative name for the entity: interest
# Entity type: OTHER
# Salience score: 0.0016560970107093453
# Mention text: interest
# Mention type: COMMON
#
#
# Representative name for the entity: choice
# Entity type: OTHER
# Salience score: 0.0016476066084578633
# Mention text: choice
# Mention type: COMMON
# Mention text: matter
# Mention type: COMMON
#
#
# Representative name for the entity: values
# Entity type: OTHER
# Salience score: 0.0016378550790250301
# Mention text: values
# Mention type: COMMON
#
#
# Representative name for the entity: methods
# Entity type: OTHER
# Salience score: 0.0016336900880560279
# Mention text: methods
# Mention type: COMMON
#
#
# Representative name for the entity: intervention
# Entity type: EVENT
# Salience score: 0.0016327626071870327
# Mention text: intervention
# Mention type: COMMON
#
#
# Representative name for the entity: brain injury
# Entity type: OTHER
# Salience score: 0.0016063761431723833
# Mention text: brain injury
# Mention type: COMMON
# Mention text: brain injury
# Mention type: COMMON
#
#
# Representative name for the entity: machines
# Entity type: CONSUMER_GOOD
# Salience score: 0.001596819725818932
# Mention text: machines
# Mention type: COMMON
#
#
# Representative name for the entity: cases
# Entity type: OTHER
# Salience score: 0.0015963998157531023
# Mention text: cases
# Mention type: COMMON
#
#
# Representative name for the entity: purchase
# Entity type: EVENT
# Salience score: 0.0015801000408828259
# Mention text: purchase
# Mention type: COMMON
#
#
# Representative name for the entity: objective function
# Entity type: OTHER
# Salience score: 0.0015737154753878713
# Mention text: objective function
# Mention type: COMMON
#
#
# Representative name for the entity: human experts
# Entity type: PERSON
# Salience score: 0.0015423152362927794
# Mention text: human experts
# Mention type: COMMON
#
#
# Representative name for the entity: human expert
# Entity type: PERSON
# Salience score: 0.0015412303619086742
# Mention text: human expert
# Mention type: COMMON
#
#
# Representative name for the entity: experience
# Entity type: OTHER
# Salience score: 0.0015392324421554804
# Mention text: experience
# Mention type: COMMON
#
#
# Representative name for the entity: experience
# Entity type: OTHER
# Salience score: 0.0015383082209154963
# Mention text: experience
# Mention type: COMMON
#
#
# Representative name for the entity: data
# Entity type: OTHER
# Salience score: 0.0015305529814213514
# Mention text: data
# Mention type: COMMON
#
#
# Representative name for the entity: models
# Entity type: CONSUMER_GOOD
# Salience score: 0.0015267611015588045
# Mention text: models
# Mention type: COMMON
#
#
# Representative name for the entity: risk prediction
# Entity type: OTHER
# Salience score: 0.0015088282525539398
# Mention text: risk prediction
# Mention type: COMMON
# Mention text: risk prediction
# Mention type: COMMON
#
#
# Representative name for the entity: PubMed
# Entity type: OTHER
# Salience score: 0.0014989568153396249
# wikipedia_url: https://en.wikipedia.org/wiki/PubMed
# mid: /m/02j3lz
# Mention text: PubMed
# Mention type: PROPER
# Mention text: PubMed
# Mention type: PROPER
# Mention text: PubMed
# Mention type: PROPER
# Mention text: PubMed
# Mention type: PROPER
#
#
# Representative name for the entity: components
# Entity type: OTHER
# Salience score: 0.0014864421682432294
# Mention text: components
# Mention type: COMMON
#
#
# Representative name for the entity: types
# Entity type: OTHER
# Salience score: 0.001469411770813167
# Mention text: types
# Mention type: COMMON
# Mention text: types
# Mention type: COMMON
#
#
# Representative name for the entity: complexity
# Entity type: OTHER
# Salience score: 0.0014283317141234875
# Mention text: complexity
# Mention type: COMMON
#
#
# Representative name for the entity: number
# Entity type: OTHER
# Salience score: 0.0013910209527239203
# Mention text: number
# Mention type: COMMON
#
#
# Representative name for the entity: approach
# Entity type: OTHER
# Salience score: 0.0013887359527871013
# Mention text: approach
# Mention type: COMMON
#
#
# Representative name for the entity: disease
# Entity type: OTHER
# Salience score: 0.0013769350480288267
# Mention text: disease
# Mention type: COMMON
#
#
# Representative name for the entity: number
# Entity type: OTHER
# Salience score: 0.0013731573708355427
# Mention text: number
# Mention type: COMMON
#
#
# Representative name for the entity: sound ML approach
# Entity type: OTHER
# Salience score: 0.0013723328011110425
# Mention text: sound ML approach
# Mention type: COMMON
#
#
# Representative name for the entity: applications
# Entity type: OTHER
# Salience score: 0.0013561791274696589
# Mention text: applications
# Mention type: COMMON
#
#
# Representative name for the entity: terms
# Entity type: OTHER
# Salience score: 0.0013542139204218984
# Mention text: terms
# Mention type: COMMON
#
#
# Representative name for the entity: terms
# Entity type: OTHER
# Salience score: 0.001350872335024178
# Mention text: terms
# Mention type: COMMON
#
#
# Representative name for the entity: diagnosis
# Entity type: OTHER
# Salience score: 0.0013457236345857382
# Mention text: diagnosis
# Mention type: COMMON
#
#
# Representative name for the entity: case
# Entity type: OTHER
# Salience score: 0.0013457236345857382
# Mention text: case
# Mention type: COMMON
#
#
# Representative name for the entity: functions
# Entity type: OTHER
# Salience score: 0.0013427062658593059
# Mention text: functions
# Mention type: COMMON
#
#
# Representative name for the entity: terms
# Entity type: OTHER
# Salience score: 0.0013427062658593059
# Mention text: terms
# Mention type: COMMON
#
#
# Representative name for the entity: function
# Entity type: OTHER
# Salience score: 0.0013427062658593059
# Mention text: function
# Mention type: COMMON
#
#
# Representative name for the entity: case
# Entity type: OTHER
# Salience score: 0.0013418127782642841
# Mention text: case
# Mention type: COMMON
#
#
# Representative name for the entity: loss function
# Entity type: OTHER
# Salience score: 0.0013409656239673495
# Mention text: loss function
# Mention type: COMMON
#
#
# Representative name for the entity: scoring function
# Entity type: OTHER
# Salience score: 0.0013409656239673495
# Mention text: scoring function
# Mention type: COMMON
#
#
# Representative name for the entity: terms
# Entity type: OTHER
# Salience score: 0.0013409656239673495
# Mention text: terms
# Mention type: COMMON
#
#
# Representative name for the entity: terms
# Entity type: OTHER
# Salience score: 0.0013393929693847895
# Mention text: terms
# Mention type: COMMON
#
#
# Representative name for the entity: support
# Entity type: OTHER
# Salience score: 0.0013295431854203343
# Mention text: support
# Mention type: COMMON
#
#
# Representative name for the entity: expert systems
# Entity type: OTHER
# Salience score: 0.0013265620218589902
# Mention text: expert systems
# Mention type: COMMON
#
#
# Representative name for the entity: Nelson et al.
# Entity type: PERSON
# Salience score: 0.0013196694198995829
# Mention text: Nelson et al.
# Mention type: PROPER
#
#
# Representative name for the entity: task
# Entity type: OTHER
# Salience score: 0.0013166989665478468
# Mention text: task
# Mention type: COMMON
#
#
# Representative name for the entity: number
# Entity type: OTHER
# Salience score: 0.0013144275872036815
# Mention text: number
# Mention type: COMMON
#
#
# Representative name for the entity: classification task
# Entity type: OTHER
# Salience score: 0.0013139935908839107
# Mention text: classification task
# Mention type: COMMON
#
#
# Representative name for the entity: regression task
# Entity type: OTHER
# Salience score: 0.0013127952115610242
# Mention text: regression task
# Mention type: COMMON
#
#
# Representative name for the entity: decision task
# Entity type: OTHER
# Salience score: 0.001310638734139502
# Mention text: decision task
# Mention type: COMMON
#
#
# Representative name for the entity: classification task
# Entity type: OTHER
# Salience score: 0.0013087394181638956
# Mention text: classification task
# Mention type: COMMON
#
#
# Representative name for the entity: y
# Entity type: OTHER
# Salience score: 0.0013087394181638956
# Mention text: y
# Mention type: COMMON
#
#
# Representative name for the entity: P
# Entity type: OTHER
# Salience score: 0.0013070427812635899
# Mention text: P
# Mention type: COMMON
#
#
# Representative name for the entity: performance metrics P
# Entity type: OTHER
# Salience score: 0.0013070427812635899
# Mention text: performance metrics P
# Mention type: COMMON
#
#
# Representative name for the entity: task
# Entity type: OTHER
# Salience score: 0.0013070427812635899
# Mention text: task
# Mention type: COMMON
#
#
# Representative name for the entity: system
# Entity type: OTHER
# Salience score: 0.0013070427812635899
# Mention text: system
# Mention type: COMMON
#
#
# Representative name for the entity: P
# Entity type: OTHER
# Salience score: 0.0013070427812635899
# Mention text: P
# Mention type: COMMON
#
#
# Representative name for the entity: system
# Entity type: OTHER
# Salience score: 0.0013070427812635899
# Mention text: system
# Mention type: COMMON
#
#
# Representative name for the entity: task
# Entity type: OTHER
# Salience score: 0.0013062579091638327
# Mention text: task
# Mention type: COMMON
#
#
# Representative name for the entity: patient
# Entity type: PERSON
# Salience score: 0.0013049810659140348
# Mention text: patient
# Mention type: COMMON
# Mention text: patient
# Mention type: COMMON
#
#
# Representative name for the entity: patients
# Entity type: PERSON
# Salience score: 0.0012892090016975999
# Mention text: patients
# Mention type: COMMON
#
#
# Representative name for the entity: titles
# Entity type: WORK_OF_ART
# Salience score: 0.001287675928324461
# Mention text: titles
# Mention type: COMMON
#
#
# Representative name for the entity: experience E
# Entity type: OTHER
# Salience score: 0.0012711388990283012
# Mention text: experience E
# Mention type: COMMON
#
#
# Representative name for the entity: E
# Entity type: OTHER
# Salience score: 0.001270375563763082
# Mention text: E
# Mention type: COMMON
#
#
# Representative name for the entity: learning process
# Entity type: OTHER
# Salience score: 0.001270375563763082
# Mention text: learning process
# Mention type: COMMON
#
#
# Representative name for the entity: pathology
# Entity type: OTHER
# Salience score: 0.001254166243597865
# Mention text: pathology
# Mention type: COMMON
#
#
# Representative name for the entity: data set
# Entity type: OTHER
# Salience score: 0.0012407200410962105
# Mention text: data set
# Mention type: COMMON
#
#
# Representative name for the entity: ML context
# Entity type: OTHER
# Salience score: 0.0012407200410962105
# Mention text: ML context
# Mention type: COMMON
#
#
# Representative name for the entity: set
# Entity type: OTHER
# Salience score: 0.0012373158242553473
# Mention text: set
# Mention type: COMMON
#
#
# Representative name for the entity: laboratory parameters
# Entity type: OTHER
# Salience score: 0.0012368116294965148
# Mention text: laboratory parameters
# Mention type: COMMON
# Mention text: laboratory parameters
# Mention type: COMMON
#
#
# Representative name for the entity: set
# Entity type: OTHER
# Salience score: 0.0012363330461084843
# Mention text: set
# Mention type: COMMON
#
#
# Representative name for the entity: ML context
# Entity type: OTHER
# Salience score: 0.0012354105710983276
# Mention text: ML context
# Mention type: COMMON
#
#
# Representative name for the entity: way
# Entity type: OTHER
# Salience score: 0.0012283604592084885
# Mention text: way
# Mention type: COMMON
#
#
# Representative name for the entity: review
# Entity type: WORK_OF_ART
# Salience score: 0.0012159065809100866
# Mention text: review
# Mention type: COMMON
#
#
# Representative name for the entity: review
# Entity type: OTHER
# Salience score: 0.0012055736733600497
# Mention text: review
# Mention type: COMMON
#
#
# Representative name for the entity: target population
# Entity type: PERSON
# Salience score: 0.0011928019812330604
# Mention text: target population
# Mention type: COMMON
#
#
# Representative name for the entity: creatinine level
# Entity type: OTHER
# Salience score: 0.0011667695362120867
# Mention text: creatinine level
# Mention type: COMMON
# Mention text: predictor
# Mention type: COMMON
#
#
# Representative name for the entity: researchers
# Entity type: PERSON
# Salience score: 0.001165082212537527
# Mention text: researchers
# Mention type: COMMON
#
#
# Representative name for the entity: case
# Entity type: OTHER
# Salience score: 0.00116463762242347
# Mention text: case
# Mention type: COMMON
#
#
# Representative name for the entity: research
# Entity type: OTHER
# Salience score: 0.0011628729989752173
# Mention text: research
# Mention type: COMMON
#
#
# Representative name for the entity: features
# Entity type: OTHER
# Salience score: 0.0011613363167271018
# Mention text: features
# Mention type: COMMON
#
#
# Representative name for the entity: measure
# Entity type: WORK_OF_ART
# Salience score: 0.0011577772675082088
# Mention text: measure
# Mention type: COMMON
#
#
# Representative name for the entity: x
# Entity type: OTHER
# Salience score: 0.0011486633447930217
# Mention text: x
# Mention type: COMMON
#
#
# Representative name for the entity: errors
# Entity type: OTHER
# Salience score: 0.0011479380773380399
# Mention text: errors
# Mention type: COMMON
#
#
# Representative name for the entity: scores
# Entity type: OTHER
# Salience score: 0.0011479380773380399
# Mention text: scores
# Mention type: COMMON
#
#
# Representative name for the entity: training data
# Entity type: OTHER
# Salience score: 0.0011456849751994014
# Mention text: training data
# Mention type: COMMON
#
#
# Representative name for the entity: Liu et al.
# Entity type: PERSON
# Salience score: 0.0011379856150597334
# Mention text: Liu et al.
# Mention type: PROPER
#
#
# Representative name for the entity: ML method
# Entity type: OTHER
# Salience score: 0.0011314419098198414
# Mention text: ML method
# Mention type: COMMON
#
#
# Representative name for the entity: approach
# Entity type: OTHER
# Salience score: 0.0011265798239037395
# Mention text: approach
# Mention type: COMMON
#
#
# Representative name for the entity: computer science
# Entity type: OTHER
# Salience score: 0.001116326660849154
# Mention text: computer science
# Mention type: COMMON
#
#
# Representative name for the entity: practitioners
# Entity type: PERSON
# Salience score: 0.001116326660849154
# Mention text: practitioners
# Mention type: COMMON
#
#
# Representative name for the entity: articles
# Entity type: WORK_OF_ART
# Salience score: 0.001116326660849154
# Mention text: articles
# Mention type: COMMON
#
#
# Representative name for the entity: abstracts
# Entity type: OTHER
# Salience score: 0.001114209764637053
# Mention text: abstracts
# Mention type: COMMON
#
#
# Representative name for the entity: articles
# Entity type: WORK_OF_ART
# Salience score: 0.001114209764637053
# Mention text: articles
# Mention type: COMMON
#
#
# Representative name for the entity: papers
# Entity type: WORK_OF_ART
# Salience score: 0.001114209764637053
# Mention text: papers
# Mention type: COMMON
#
#
# Representative name for the entity: scale
# Entity type: OTHER
# Salience score: 0.0011118929833173752
# Mention text: scale
# Mention type: COMMON
#
#
# Representative name for the entity: creatinine levels
# Entity type: OTHER
# Salience score: 0.0011047407751902938
# Mention text: creatinine levels
# Mention type: COMMON
#
#
# Representative name for the entity: prognosis
# Entity type: OTHER
# Salience score: 0.0011038027005270123
# Mention text: prognosis
# Mention type: COMMON
#
#
# Representative name for the entity: research journal article
# Entity type: WORK_OF_ART
# Salience score: 0.0011007980210706592
# Mention text: one
# Mention type: COMMON
# Mention text: research journal article
# Mention type: COMMON
#
#
# Representative name for the entity: human programmers
# Entity type: PERSON
# Salience score: 0.0011005945270881057
# Mention text: human programmers
# Mention type: COMMON
#
#
# Representative name for the entity: machine learning
# Entity type: OTHER
# Salience score: 0.0010978723876178265
# Mention text: machine learning
# Mention type: COMMON
# Mention text: machine learning
# Mention type: COMMON
#
#
# Representative name for the entity: ML model
# Entity type: OTHER
# Salience score: 0.0010838793823495507
# Mention text: ML model
# Mention type: COMMON
#
#
# Representative name for the entity: model
# Entity type: OTHER
# Salience score: 0.0010834925342351198
# Mention text: model
# Mention type: COMMON
#
#
# Representative name for the entity: model
# Entity type: OTHER
# Salience score: 0.001082396018318832
# Mention text: model
# Mention type: COMMON
#
#
# Representative name for the entity: Evaluation
# Entity type: WORK_OF_ART
# Salience score: 0.0010817211586982012
# Mention text: Evaluation
# Mention type: COMMON
# Mention text: evaluation
# Mention type: COMMON
#
#
# Representative name for the entity: model
# Entity type: OTHER
# Salience score: 0.00107956666033715
# Mention text: model
# Mention type: COMMON
#
#
# Representative name for the entity: authors
# Entity type: PERSON
# Salience score: 0.001063954783603549
# Mention text: authors
# Mention type: COMMON
# Mention text: authors
# Mention type: COMMON
#
#
# Representative name for the entity: representation
# Entity type: OTHER
# Salience score: 0.0010535427136346698
# Mention text: representation
# Mention type: COMMON
#
#
# Representative name for the entity: representation
# Entity type: OTHER
# Salience score: 0.0010535427136346698
# Mention text: representation
# Mention type: COMMON
#
#
# Representative name for the entity: literature
# Entity type: OTHER
# Salience score: 0.0010506520047783852
# Mention text: literature
# Mention type: COMMON
#
#
# Representative name for the entity: fact
# Entity type: OTHER
# Salience score: 0.0010469368426129222
# Mention text: fact
# Mention type: COMMON
#
#
# Representative name for the entity: training data
# Entity type: OTHER
# Salience score: 0.0010458803735673428
# Mention text: training data
# Mention type: COMMON
#
#
# Representative name for the entity: representation
# Entity type: OTHER
# Salience score: 0.0010457088937982917
# Mention text: representation
# Mention type: COMMON
#
#
# Representative name for the entity: methods
# Entity type: OTHER
# Salience score: 0.001034940010868013
# Mention text: methods
# Mention type: COMMON
#
#
# Representative name for the entity: shopping cart
# Entity type: OTHER
# Salience score: 0.001010917709209025
# Mention text: shopping cart
# Mention type: COMMON
#
#
# Representative name for the entity: representation
# Entity type: OTHER
# Salience score: 0.001010165549814701
# Mention text: representation
# Mention type: COMMON
#
#
# Representative name for the entity: queries
# Entity type: OTHER
# Salience score: 0.001000425429083407
# Mention text: queries
# Mention type: COMMON
#
#
# Representative name for the entity: physicians
# Entity type: PERSON
# Salience score: 0.0009987818775698543
# Mention text: physicians
# Mention type: COMMON
#
#
# Representative name for the entity: portions
# Entity type: OTHER
# Salience score: 0.0009938075672835112
# Mention text: portions
# Mention type: COMMON
#
#
# Representative name for the entity: human
# Entity type: PERSON
# Salience score: 0.000987576087936759
# Mention text: human
# Mention type: COMMON
#
#
# Representative name for the entity: example
# Entity type: OTHER
# Salience score: 0.000987576087936759
# Mention text: example
# Mention type: COMMON
#
#
# Representative name for the entity: performance metrics
# Entity type: OTHER
# Salience score: 0.0009869829518720508
# Mention text: performance metrics
# Mention type: COMMON
#
#
# Representative name for the entity: advantage
# Entity type: OTHER
# Salience score: 0.0009767499286681414
# Mention text: advantage
# Mention type: COMMON
#
#
# Representative name for the entity: use
# Entity type: OTHER
# Salience score: 0.0009730677702464163
# Mention text: use
# Mention type: COMMON
#
#
# Representative name for the entity: label
# Entity type: ORGANIZATION
# Salience score: 0.0009471674566157162
# Mention text: label
# Mention type: COMMON
#
#
# Representative name for the entity: journal
# Entity type: WORK_OF_ART
# Salience score: 0.0009353146888315678
# Mention text: journal
# Mention type: COMMON
#
#
# Representative name for the entity: infancy
# Entity type: OTHER
# Salience score: 0.0009353146888315678
# Mention text: infancy
# Mention type: COMMON
#
#
# Representative name for the entity: ALL
# Entity type: OTHER
# Salience score: 0.0009338404051959515
# Mention text: ALL
# Mention type: COMMON
# Mention text: ALL
# Mention type: COMMON
# Mention text: ALL
# Mention type: COMMON
#
#
# Representative name for the entity: laboratory
# Entity type: LOCATION
# Salience score: 0.0009333015768788755
# Mention text: laboratory
# Mention type: COMMON
#
#
# Representative name for the entity: journals
# Entity type: WORK_OF_ART
# Salience score: 0.000933217175770551
# Mention text: journals
# Mention type: COMMON
#
#
# Representative name for the entity: research
# Entity type: OTHER
# Salience score: 0.00093311897944659
# Mention text: research
# Mention type: COMMON
# Mention text: research
# Mention type: COMMON
#
#
# Representative name for the entity: increase
# Entity type: OTHER
# Salience score: 0.0009314474300481379
# Mention text: increase
# Mention type: COMMON
#
#
# Representative name for the entity: models
# Entity type: CONSUMER_GOOD
# Salience score: 0.0009313414921052754
# Mention text: models
# Mention type: COMMON
#
#
# Representative name for the entity: data
# Entity type: OTHER
# Salience score: 0.0009294823976233602
# Mention text: data
# Mention type: COMMON
#
#
# Representative name for the entity: measurement scale
# Entity type: OTHER
# Salience score: 0.000925285741686821
# Mention text: measurement scale
# Mention type: COMMON
#
#
# Representative name for the entity: order
# Entity type: OTHER
# Salience score: 0.0009227467817254364
# Mention text: order
# Mention type: COMMON
#
#
# Representative name for the entity: dimensions
# Entity type: OTHER
# Salience score: 0.0009213256998918951
# Mention text: dimensions
# Mention type: COMMON
#
#
# Representative name for the entity: capability
# Entity type: OTHER
# Salience score: 0.0009206774411723018
# Mention text: capability
# Mention type: COMMON
#
#
# Representative name for the entity: improvement
# Entity type: OTHER
# Salience score: 0.0009200646891258657
# Mention text: improvement
# Mention type: COMMON
#
#
# Representative name for the entity: part
# Entity type: OTHER
# Salience score: 0.0009200646891258657
# Mention text: part
# Mention type: COMMON
#
#
# Representative name for the entity: software
# Entity type: CONSUMER_GOOD
# Salience score: 0.0009194837184622884
# Mention text: software
# Mention type: COMMON
#
#
# Representative name for the entity: parameters
# Entity type: OTHER
# Salience score: 0.0009189669508486986
# Mention text: parameters
# Mention type: COMMON
#
#
# Representative name for the entity: model
# Entity type: OTHER
# Salience score: 0.0009059266885742545
# Mention text: model
# Mention type: COMMON
#
#
# Representative name for the entity: model
# Entity type: PERSON
# Salience score: 0.0009059266885742545
# Mention text: model
# Mention type: COMMON
#
#
# Representative name for the entity: model
# Entity type: OTHER
# Salience score: 0.0009059266885742545
# Mention text: model
# Mention type: COMMON
#
#
# Representative name for the entity: Model
# Entity type: PERSON
# Salience score: 0.0009049565414898098
# Mention text: Model
# Mention type: COMMON
#
#
# Representative name for the entity: model
# Entity type: OTHER
# Salience score: 0.0009021090227179229
# Mention text: model
# Mention type: COMMON
#
#
# Representative name for the entity: model
# Entity type: OTHER
# Salience score: 0.0009021090227179229
# Mention text: model
# Mention type: COMMON
#
#
# Representative name for the entity: model
# Entity type: OTHER
# Salience score: 0.000899850158020854
# Mention text: model
# Mention type: COMMON
#
#
# Representative name for the entity: ML model
# Entity type: OTHER
# Salience score: 0.0008995623793452978
# Mention text: ML model
# Mention type: COMMON
#
#
# Representative name for the entity: ML model
# Entity type: OTHER
# Salience score: 0.0008995623793452978
# Mention text: ML model
# Mention type: COMMON
#
#
# Representative name for the entity: model
# Entity type: OTHER
# Salience score: 0.0008992819930426776
# Mention text: model
# Mention type: COMMON
#
#
# Representative name for the entity: model
# Entity type: OTHER
# Salience score: 0.0008992819930426776
# Mention text: model
# Mention type: COMMON
#
#
# Representative name for the entity: model
# Entity type: OTHER
# Salience score: 0.0008992819930426776
# Mention text: model
# Mention type: COMMON
#
#
# Representative name for the entity: model
# Entity type: OTHER
# Salience score: 0.0008984814630821347
# Mention text: model
# Mention type: COMMON
#
#
# Representative name for the entity: testing data
# Entity type: OTHER
# Salience score: 0.0008911708137020469
# Mention text: testing data
# Mention type: COMMON
#
#
# Representative name for the entity: Experience data
# Entity type: OTHER
# Salience score: 0.0008911708137020469
# Mention text: Experience data
# Mention type: COMMON
#
#
# Representative name for the entity: data
# Entity type: OTHER
# Salience score: 0.0008902164408937097
# Mention text: data
# Mention type: COMMON
#
#
# Representative name for the entity: data
# Entity type: OTHER
# Salience score: 0.0008893394260667264
# Mention text: data
# Mention type: COMMON
#
#
# Representative name for the entity: data
# Entity type: OTHER
# Salience score: 0.0008893394260667264
# Mention text: data
# Mention type: COMMON
#
#
# Representative name for the entity: data
# Entity type: OTHER
# Salience score: 0.0008885282441042364
# Mention text: data
# Mention type: COMMON
#
#
# Representative name for the entity: data
# Entity type: OTHER
# Salience score: 0.00088741525541991
# Mention text: data
# Mention type: COMMON
#
#
# Representative name for the entity: data
# Entity type: OTHER
# Salience score: 0.0008867323631420732
# Mention text: data
# Mention type: COMMON
#
#
# Representative name for the entity: training data
# Entity type: OTHER
# Salience score: 0.000886090099811554
# Mention text: training data
# Mention type: COMMON
#
#
# Representative name for the entity: data
# Entity type: OTHER
# Salience score: 0.000886090099811554
# Mention text: data
# Mention type: COMMON
#
#
# Representative name for the entity: training data
# Entity type: OTHER
# Salience score: 0.0008851931779645383
# Mention text: training data
# Mention type: COMMON
#
#
# Representative name for the entity: test data
# Entity type: OTHER
# Salience score: 0.0008851931779645383
# Mention text: test data
# Mention type: COMMON
#
#
# Representative name for the entity: data
# Entity type: OTHER
# Salience score: 0.0008851931779645383
# Mention text: data
# Mention type: COMMON
#
#
# Representative name for the entity: training data
# Entity type: OTHER
# Salience score: 0.0008831130689941347
# Mention text: training data
# Mention type: COMMON
#
#
# Representative name for the entity: data
# Entity type: OTHER
# Salience score: 0.0008831130689941347
# Mention text: data
# Mention type: COMMON
#
#
# Representative name for the entity: Machine learning
# Entity type: OTHER
# Salience score: 0.0008575944812037051
# Mention text: Machine learning
# Mention type: COMMON
# Mention text: machine learning
# Mention type: COMMON
#
#
# Representative name for the entity: attention
# Entity type: OTHER
# Salience score: 0.0008530151681043208
# Mention text: attention
# Mention type: COMMON
#
#
# Representative name for the entity: purposes
# Entity type: OTHER
# Salience score: 0.0008530151681043208
# Mention text: purposes
# Mention type: COMMON
#
#
# Representative name for the entity: light
# Entity type: OTHER
# Salience score: 0.0008511021733283997
# Mention text: light
# Mention type: COMMON
#
#
# Representative name for the entity: editorials
# Entity type: OTHER
# Salience score: 0.0008511021733283997
# Mention text: editorials
# Mention type: COMMON
#
#
# Representative name for the entity: nature
# Entity type: OTHER
# Salience score: 0.0008457651711069047
# Mention text: nature
# Mention type: COMMON
#
#
# Representative name for the entity: ratio
# Entity type: OTHER
# Salience score: 0.0008422680548392236
# Mention text: ratio
# Mention type: COMMON
#
#
# Representative name for the entity: mapping
# Entity type: OTHER
# Salience score: 0.0008415527991019189
# Mention text: mapping
# Mention type: COMMON
#
#
# Representative name for the entity: questions
# Entity type: OTHER
# Salience score: 0.0008408842259086668
# Mention text: questions
# Mention type: COMMON
#
#
# Representative name for the entity: attributes
# Entity type: OTHER
# Salience score: 0.0008402566891163588
# Mention text: attributes
# Mention type: COMMON
#
#
# Representative name for the entity: attempts
# Entity type: OTHER
# Salience score: 0.0008385767578147352
# Mention text: attempts
# Mention type: COMMON
#
#
# Representative name for the entity: expert systems
# Entity type: OTHER
# Salience score: 0.0008385448018088937
# Mention text: expert systems
# Mention type: COMMON
#
#
# Representative name for the entity: things
# Entity type: OTHER
# Salience score: 0.0008380730869248509
# Mention text: things
# Mention type: COMMON
#
#
# Representative name for the entity: ML problems
# Entity type: OTHER
# Salience score: 0.0008375931647606194
# Mention text: ML problems
# Mention type: COMMON
#
#
# Representative name for the entity: combination
# Entity type: OTHER
# Salience score: 0.0008375931647606194
# Mention text: combination
# Mention type: COMMON
#
#
# Representative name for the entity: principle
# Entity type: OTHER
# Salience score: 0.0008304714574478567
# Mention text: principle
# Mention type: COMMON
#
#
# Representative name for the entity: calcium
# Entity type: OTHER
# Salience score: 0.0008238765876740217
# Mention text: calcium
# Mention type: COMMON
# Mention text: calcium
# Mention type: COMMON
#
#
# Representative name for the entity: loss function
# Entity type: OTHER
# Salience score: 0.0008226304780691862
# Mention text: loss function
# Mention type: COMMON
#
#
# Representative name for the entity: Google Scholar
# Entity type: OTHER
# Salience score: 0.000792887934949249
# mid: /m/057mg4
# wikipedia_url: https://en.wikipedia.org/wiki/Google_Scholar
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
# Mention text: Google Scholar
# Mention type: PROPER
#
#
# Representative name for the entity: article content
# Entity type: WORK_OF_ART
# Salience score: 0.0007904475787654519
# Mention text: article content
# Mention type: COMMON
#
#
# Representative name for the entity: trade-off
# Entity type: EVENT
# Salience score: 0.0007838909514248371
# Mention text: trade-off
# Mention type: COMMON
#
#
# Representative name for the entity: model
# Entity type: CONSUMER_GOOD
# Salience score: 0.000780977017711848
# Mention text: model
# Mention type: COMMON
#
#
# Representative name for the entity: curve
# Entity type: OTHER
# Salience score: 0.0007795848068781197
# ...
# Entity type: NUMBER
# Salience score: 0.0
# value: 33
# Mention text: 33
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 2013
# Entity type: NUMBER
# Salience score: 0.0
# value: 2013
# Mention text: 2013
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 146
# Entity type: NUMBER
# Salience score: 0.0
# value: 146
# Mention text: 146
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 3
# Entity type: NUMBER
# Salience score: 0.0
# value: 3
# Mention text: 3
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 20
# Entity type: NUMBER
# Salience score: 0.0
# value: 20
# Mention text: 20
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 61
# Entity type: NUMBER
# Salience score: 0.0
# value: 61
# Mention text: 61
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 1213
# Entity type: NUMBER
# Salience score: 0.0
# value: 1213
# Mention text: 1213
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 2017
# Entity type: NUMBER
# Salience score: 0.0
# value: 2017
# Mention text: 2017
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 315
# Entity type: NUMBER
# Salience score: 0.0
# value: 315
# Mention text: 315
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 98.0
# Entity type: NUMBER
# Salience score: 0.0
# value: 98.000000
# Mention text: 98.0
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 100
# Entity type: NUMBER
# Salience score: 0.0
# value: 100
# Mention text: 100
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 28
# Entity type: NUMBER
# Salience score: 0.0
# value: 28
# Mention text: 28
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: two
# Entity type: NUMBER
# Salience score: 0.0
# value: 2
# Mention text: two
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 300
# Entity type: NUMBER
# Salience score: 0.0
# value: 300
# Mention text: 300
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 48
# Entity type: NUMBER
# Salience score: 0.0
# value: 48
# Mention text: 48
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 4
# Entity type: NUMBER
# Salience score: 0.0
# value: 4
# Mention text: 4
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 42
# Entity type: NUMBER
# Salience score: 0.0
# value: 42
# Mention text: 42
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 39
# Entity type: NUMBER
# Salience score: 0.0
# value: 39
# Mention text: 39
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 31
# Entity type: NUMBER
# Salience score: 0.0
# value: 31
# Mention text: 31
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 1319
# Entity type: NUMBER
# Salience score: 0.0
# value: 1319
# Mention text: 1319
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 8
# Entity type: NUMBER
# Salience score: 0.0
# value: 8
# Mention text: 8
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 778
# Entity type: NUMBER
# Salience score: 0.0
# value: 778
# Mention text: 778
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 88
# Entity type: NUMBER
# Salience score: 0.0
# value: 88
# Mention text: 88
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 1475
# Entity type: NUMBER
# Salience score: 0.0
# value: 1475
# Mention text: 1475
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 551
# Entity type: NUMBER
# Salience score: 0.0
# value: 551
# Mention text: 551
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 6
# Entity type: NUMBER
# Salience score: 0.0
# value: 6
# Mention text: 6
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 27
# Entity type: NUMBER
# Salience score: 0.0
# value: 27
# Mention text: 27
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 2005
# Entity type: NUMBER
# Salience score: 0.0
# value: 2005
# Mention text: 2005
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 2017
# Entity type: NUMBER
# Salience score: 0.0
# value: 2017
# Mention text: 2017
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: five
# Entity type: NUMBER
# Salience score: 0.0
# value: 5
# Mention text: five
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: four
# Entity type: NUMBER
# Salience score: 0.0
# value: 4
# Mention text: four
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 95.6
# Entity type: NUMBER
# Salience score: 0.0
# value: 95.600000
# Mention text: 95.6
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 15
# Entity type: NUMBER
# Salience score: 0.0
# value: 15
# Mention text: 15
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 30
# Entity type: NUMBER
# Salience score: 0.0
# value: 30
# Mention text: 30
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 1021
# Entity type: NUMBER
# Salience score: 0.0
# value: 1021
# Mention text: 1021
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 2016
# Entity type: NUMBER
# Salience score: 0.0
# value: 2016
# Mention text: 2016
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 17
# Entity type: NUMBER
# Salience score: 0.0
# value: 17
# Mention text: 17
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 7
# Entity type: NUMBER
# Salience score: 0.0
# value: 7
# Mention text: 7
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 44
# Entity type: NUMBER
# Salience score: 0.0
# value: 44
# Mention text: 44
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 2012
# Entity type: NUMBER
# Salience score: 0.0
# value: 2012
# Mention text: 2012
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 22
# Entity type: NUMBER
# Salience score: 0.0
# value: 22
# Mention text: 22
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 2016
# Entity type: NUMBER
# Salience score: 0.0
# value: 2016
# Mention text: 2016
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 2007
# Entity type: NUMBER
# Salience score: 0.0
# value: 2007
# Mention text: 2007
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 50
# Entity type: NUMBER
# Salience score: 0.0
# value: 50
# Mention text: 50
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: five
# Entity type: NUMBER
# Salience score: 0.0
# value: 5
# Mention text: five
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 2016
# Entity type: NUMBER
# Salience score: 0.0
# value: 2016
# Mention text: 2016
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 21.1
# Entity type: NUMBER
# Salience score: 0.0
# value: 21.100000
# Mention text: 21.1
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 9
# Entity type: NUMBER
# Salience score: 0.0
# value: 9
# Mention text: 9
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 95
# Entity type: NUMBER
# Salience score: 0.0
# value: 95
# Mention text: 95
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 2010
# Entity type: NUMBER
# Salience score: 0.0
# value: 2010
# Mention text: 2010
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 18
# Entity type: NUMBER
# Salience score: 0.0
# value: 18
# Mention text: 18
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 757
# Entity type: NUMBER
# Salience score: 0.0
# value: 757
# Mention text: 757
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 10
# Entity type: NUMBER
# Salience score: 0.0
# value: 10
# Mention text: 10
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 2014
# Entity type: NUMBER
# Salience score: 0.0
# value: 2014
# Mention text: 2014
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 1
# Entity type: NUMBER
# Salience score: 0.0
# value: 1
# Mention text: 1
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 24
# Entity type: NUMBER
# Salience score: 0.0
# value: 24
# Mention text: 24
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 2
# Entity type: NUMBER
# Salience score: 0.0
# value: 2
# Mention text: 2
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 417
# Entity type: NUMBER
# Salience score: 0.0
# value: 417
# Mention text: 417
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 7
# Entity type: NUMBER
# Salience score: 0.0
# value: 7
# Mention text: 7
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 1644
# Entity type: NUMBER
# Salience score: 0.0
# value: 1644
# Mention text: 1644
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 78
# Entity type: NUMBER
# Salience score: 0.0
# value: 78
# Mention text: 78
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 2013
# Entity type: NUMBER
# Salience score: 0.0
# value: 2013
# Mention text: 2013
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 14
# Entity type: NUMBER
# Salience score: 0.0
# value: 14
# Mention text: 14
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 13
# Entity type: NUMBER
# Salience score: 0.0
# value: 13
# Mention text: 13
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: three
# Entity type: NUMBER
# Salience score: 0.0
# value: 3
# Mention text: three
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 36
# Entity type: NUMBER
# Salience score: 0.0
# value: 36
# Mention text: 36
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 94.3
# Entity type: NUMBER
# Salience score: 0.0
# value: 94.300000
# Mention text: 94.3
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 40
# Entity type: NUMBER
# Salience score: 0.0
# value: 40
# Mention text: 40
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 2016
# Entity type: NUMBER
# Salience score: 0.0
# value: 2016
# Mention text: 2016
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 11
# Entity type: NUMBER
# Salience score: 0.0
# value: 11
# Mention text: 11
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: seven
# Entity type: NUMBER
# Salience score: 0.0
# value: 7
# Mention text: seven
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 13
# Entity type: NUMBER
# Salience score: 0.0
# value: 13
# Mention text: 13
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 6
# Entity type: NUMBER
# Salience score: 0.0
# value: 6
# Mention text: 6
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 100
# Entity type: NUMBER
# Salience score: 0.0
# value: 100
# Mention text: 100
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 5
# Entity type: NUMBER
# Salience score: 0.0
# value: 5
# Mention text: 5
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 0.95
# Entity type: NUMBER
# Salience score: 0.0
# value: 0.950000
# Mention text: 0.95
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 13
# Entity type: NUMBER
# Salience score: 0.0
# value: 13
# Mention text: 13
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 227
# Entity type: NUMBER
# Salience score: 0.0
# value: 227
# Mention text: 227
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 8
# Entity type: NUMBER
# Salience score: 0.0
# value: 8
# Mention text: 8
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 38
# Entity type: NUMBER
# Salience score: 0.0
# value: 38
# Mention text: 38
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 8
# Entity type: NUMBER
# Salience score: 0.0
# value: 8
# Mention text: 8
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 4.1 million
# Entity type: NUMBER
# Salience score: 0.0
# value: 4100000.000000
# Mention text: 4.1 million
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 1113
# Entity type: NUMBER
# Salience score: 0.0
# value: 1113
# Mention text: 1113
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 30
# Entity type: NUMBER
# Salience score: 0.0
# value: 30
# Mention text: 30
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 1997
# Entity type: NUMBER
# Salience score: 0.0
# value: 1997
# Mention text: 1997
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 12
# Entity type: NUMBER
# Salience score: 0.0
# value: 12
# Mention text: 12
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 14
# Entity type: NUMBER
# Salience score: 0.0
# value: 14
# Mention text: 14
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 11,830
# Entity type: NUMBER
# Salience score: 0.0
# value: 11830
# Mention text: 11,830
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 736
# Entity type: NUMBER
# Salience score: 0.0
# value: 736
# Mention text: 736
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 51
# Entity type: NUMBER
# Salience score: 0.0
# value: 51
# Mention text: 51
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 628
# Entity type: NUMBER
# Salience score: 0.0
# value: 628
# Mention text: 628
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 1
# Entity type: NUMBER
# Salience score: 0.0
# value: 1
# Mention text: 1
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 125
# Entity type: NUMBER
# Salience score: 0.0
# value: 125
# Mention text: 125
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 26
# Entity type: NUMBER
# Salience score: 0.0
# value: 26
# Mention text: 26
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 32
# Entity type: NUMBER
# Salience score: 0.0
# value: 32
# Mention text: 32
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 34
# Entity type: NUMBER
# Salience score: 0.0
# value: 34
# Mention text: 34
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 18
# Entity type: NUMBER
# Salience score: 0.0
# value: 18
# Mention text: 18
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 2155
# Entity type: NUMBER
# Salience score: 0.0
# value: 2155
# Mention text: 2155
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 39
# Entity type: NUMBER
# Salience score: 0.0
# value: 39
# Mention text: 39
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 5 billion
# Entity type: NUMBER
# Salience score: 0.0
# value: 5000000000.000000
# Mention text: 5 billion
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 80
# Entity type: NUMBER
# Salience score: 0.0
# value: 80
# Mention text: 80
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 2006
# Entity type: NUMBER
# Salience score: 0.0
# value: 2006
# Mention text: 2006
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 781
# Entity type: NUMBER
# Salience score: 0.0
# value: 781
# Mention text: 781
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 1000
# Entity type: NUMBER
# Salience score: 0.0
# value: 1000
# Mention text: 1000
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 5
# Entity type: NUMBER
# Salience score: 0.0
# value: 5
# Mention text: 5
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 250,000
# Entity type: NUMBER
# Salience score: 0.0
# value: 250000
# Mention text: 250,000
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 2016
# Entity type: NUMBER
# Salience score: 0.0
# value: 2016
# Mention text: 2016
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 1
# Entity type: NUMBER
# Salience score: 0.0
# value: 1
# Mention text: 1
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 2.0
# Entity type: NUMBER
# Salience score: 0.0
# value: 2.000000
# Mention text: 2.0
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 1000
# Entity type: NUMBER
# Salience score: 0.0
# value: 1000
# Mention text: 1000
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 0.81
# Entity type: NUMBER
# Salience score: 0.0
# value: 0.810000
# Mention text: 0.81
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 1009
# Entity type: NUMBER
# Salience score: 0.0
# value: 1009
# Mention text: 1009
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 13
# Entity type: NUMBER
# Salience score: 0.0
# value: 13
# Mention text: 13
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 2016
# Entity type: NUMBER
# Salience score: 0.0
# value: 2016
# Mention text: 2016
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 2017
# Entity type: NUMBER
# Salience score: 0.0
# value: 2017
# Mention text: 2017
# Mention type: TYPE_UNKNOWN
#
#
# Representative name for the entity: 2018
# Entity type: NUMBER
# Salience score: 0.0
# value: 2018
# Mention text: 2018
# Mention type: TYPE_UNKNOWN
#
#
# Language of the text: en
